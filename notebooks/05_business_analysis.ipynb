# %% [markdown]
# # SuperMarketIQ: 05 - Business Analysis & Core Question Solutions
#
# **Project:** IBM Data Analyst with AI Masterclass Internship
# **Input:** data/processed/enriched_supermarket_data.csv
# **Output:** Summary tables in outputs/tables/
# **Objective:** Systematically address the 15 Core Business Questions defined in the project roadmap and export structured business summary tables.

# %%
import pandas as pd
import os
import sys

sys.path.append(os.path.join('..', 'src'))
from analysis import run_business_analysis

tables = run_business_analysis(file_path=os.path.join('..', 'data', 'processed', 'enriched_supermarket_data.csv'),
                               output_dir=os.path.join('..', 'outputs', 'tables'))
print('Generated summary tables:', len(tables))
