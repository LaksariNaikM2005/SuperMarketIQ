# %% [markdown]
# # SuperMarketIQ: 04 - Comprehensive Exploratory Data Analysis (EDA)
#
# **Project:** IBM Data Analyst with AI Masterclass Internship
# **Input:** data/processed/enriched_supermarket_data.csv
# **Output:** Chart plots saved to outputs/charts/
# **Objective:** Perform univariate, bivariate, and multivariate distribution analysis across revenue, branches, categories, pricing, ratings, and customer demographics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

sys.path.append(os.path.join('..', 'src'))
from visualization import generate_all_charts

df = pd.read_csv(os.path.join('..', 'data', 'processed', 'enriched_supermarket_data.csv'))
print(f'Enriched Dataset Loaded: {df.shape}')

# %% [markdown]
# ## 1. Summary Statistics & Overview

# %%
display(df.describe().T)

# %% [markdown]
# ## 2. Execute Executive Visualization Suite

# %%
charts = generate_all_charts(df, output_dir=os.path.join('..', 'outputs', 'charts'))
print('Generated charts:', len(charts))
